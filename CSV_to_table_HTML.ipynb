# %%
import pandas as pd

# %%
encoding='utf-8'
df = pd.read_csv('cities.csv')
df.head()
# Out:
#    City_ID       City Country  Temperature (F)  Latitude  Longitude  \
# 0        0     Murgab      TM            77.00     37.50      61.97
# 1        1      Tabuk      PH            78.31     17.41     121.44
# 2        2   Hermanus      ZA            37.27    -34.42      19.24
# 3        3    Rikitea      PF            74.89    -23.12    -134.97
# 4        4  Cape Town      ZA            46.40    -33.93      18.42
#
#    Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0            36               0              4.61
# 1            85              56              1.74
# 2            75               0              3.49
# 3           100              44              7.52
# 4            75               0              4.70

# %%
html_table = df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City_ID</th>\n      <th>City</th>\n      <th>Country</th>\n      <th>Temperature (F)</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Humidity (%)</th>\n      <th>Cloudiness (%)</th>\n      <th>Wind Speed (mph)</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>Murgab</td>\n      <td>TM</td>\n      <td>77.00</td>\n      <td>37.50</td>\n      <td>61.97</td>\n      <td>36</td>\n      <td>0</td>\n      <td>4.61</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>Tabuk</td>\n      <td>PH</td>\n      <td>78.31</td>\n      <td>17.41</td>\n      <td>121.44</td>\n      <td>85</td>\n      <td>56</td>\n      <td>1.74</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>Hermanus</td>\n      <td>ZA</td>\n      <td>37.27</td>\n      <td>-34.42</td>\n      <td>19.24</td>\n      <td>7
# ...

# %%
html_table.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>City_ID</th>      <th>City</th>      <th>Country</th>      <th>Temperature (F)</th>      <th>Latitude</th>      <th>Longitude</th>      <th>Humidity (%)</th>      <th>Cloudiness (%)</th>      <th>Wind Speed (mph)</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>0</td>      <td>Murgab</td>      <td>TM</td>      <td>77.00</td>      <td>37.50</td>      <td>61.97</td>      <td>36</td>      <td>0</td>      <td>4.61</td>    </tr>    <tr>      <th>1</th>      <td>1</td>      <td>Tabuk</td>      <td>PH</td>      <td>78.31</td>      <td>17.41</td>      <td>121.44</td>      <td>85</td>      <td>56</td>      <td>1.74</td>    </tr>    <tr>      <th>2</th>      <td>2</td>      <td>Hermanus</td>      <td>ZA</td>      <td>37.27</td>      <td>-34.42</td>      <td>19.24</td>      <td>75</td>      <td>0</td>      <td>3.49</td>    </tr>    <tr>      <th>3</th>      <td>3</td>      
# ...

# %%
table    = df.to_html(classes='utf8')
